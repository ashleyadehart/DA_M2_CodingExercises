# %% [markdown]
# # Section 1: Pandas: A Data Analyst's Best Friend

# %%
import pandas as pd

data = {
"Name": [
    "Alice", "Bob", "Charlie", "David", "Evelyn",
    "Frank", "Grace", "Henry", "Isla", "Jack",
    "Karen", "Leo", "Mia", "Noah", "Olivia",
    "Paul", "Quinn", "Ruby", "Sam", "Tina"
],
"Age": [25, 32, 37, 29, 41, 28, 34, 45, 26, 31, 39, 27, 33, 36, 30, 42, 24, 38, 35, 29],
"Department": [
    "HR", "Engineering", "Sales", "Marketing", "Engineering",
    "Finance", "Support", "Operations", "HR", "Sales",
    "Engineering", "Support", "Marketing", "Finance", "Operations",
    "Engineering", "HR", "Sales", "Support", "Marketing"
],
"Salary": [
    50000, 75000, 62000, 58000, 80000,
    54000, 52000, 70000, 51000, 64000,
    82000, 53000, 60000, 56000, 68000,
    79000, 49500, 65500, 54500, 61000
],
}

df = pd.DataFrame(data)

# %%
# View the first five rows of the DataFrame
print(df.head())
# Out:
#       Name  Age   Department  Salary
# 0    Alice   25           HR   50000
# 1      Bob   32  Engineering   75000
# 2  Charlie   37        Sales   62000
# 3    David   29    Marketing   58000
# 4   Evelyn   41  Engineering   80000

# %%
# View the last five rows of the DataFrame
print(df.tail())
# Out:
#      Name  Age   Department  Salary
# 15   Paul   42  Engineering   79000
# 16  Quinn   24           HR   49500
# 17   Ruby   38        Sales   65500
# 18    Sam   35      Support   54500
# 19   Tina   29    Marketing   61000

# %%
# Get basic info about the DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     object
#  1   Age         20 non-null     int64
#  2   Department  20 non-null     object
#  3   Salary      20 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 772.0+ bytes
# None

# %%
# Check the shape of the DataFrame
print(df.shape)
# Out:
# (20, 4)

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Use .loc to get the name and age of the passenger with index 12
print(df.loc[12, ["Name", "Age"]])
# Out:
# Name    Saundercock, Mr. William Henry
# Age                               20.0
# Name: 12, dtype: object

# %%
# Use .iloc to get the first 5 rows and first 3 columns
print(df.iloc[:5, :3])
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
# Use .loc to get all passengers in 1st class who are female
print(df.loc[(df["Pclass"] == 1) & (df["Sex"] == "female")])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [94 rows x 12 columns]

# %%
# Use .iloc to get the age of the 10th passenger (by position)
print(df.iloc[9, df.columns.get_loc("Age")])
# Out:
# 14.0

# %%
# Use .loc to get the Fare and Survived values for passengers with index 100 to 105
print(df.loc[100:105, ["Fare", "Survived"]])
# Out:
#         Fare  Survived
# 100   7.8958         0
# 101   7.8958         0
# 102  77.2875         0
# 103   8.6542         0
# 104   7.9250         0
# 105   7.8958         0

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Summarize numeric columns
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Use .value_counts() to see counts for embarkation ports
print(df["Embarked"].value_counts())
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Use .value_counts() to count passenger classes
print(df["Pclass"].value_counts())
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# Show the average (mean) age of passengers
print(df["Age"].mean())
# Out:
# 29.69911764705882

# %%
# Show the maximum fare paid
print(df["Fare"].max())
# Out:
# 512.3292

# %%
# Show how many unique names are in the dataset
print(df["Name"].nunique())
# Out:
# 891

# %%
# Show counts for values in the Sex column
print(df["Sex"].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Show how many unique values are in each column
print(df.nunique())
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # Section 2: Clean & Tidy Data

# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "David"],
"Age": [25, 30, 35, 40],
"City": ["NYC", "LA", "Chicago", "Miami"],
"Email": ["a@example.com", "b@example.com", "c@example.com", "d@example.com"],
}

df = pd.DataFrame(data)

# %%
# Drop the Email column and store the result in a new variable
new_df = df.drop(columns=["Email"])
print(new_df)
# Out:
#       Name  Age     City
# 0    Alice   25      NYC
# 1      Bob   30       LA
# 2  Charlie   35  Chicago
# 3    David   40    Miami

# %%
# Drop the row with index 2 in place
df.drop(index=2, inplace=True)
print(df)
# Out:
#     Name  Age   City          Email
# 0  Alice   25    NYC  a@example.com
# 1    Bob   30     LA  b@example.com
# 3  David   40  Miami  d@example.com

# %%
# Drop the City and Email columns, and assign the result back to df
df = df.drop(columns=["City", "Email"])
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 3  David   40

# %%
# Drop the first and last row, and store the result in df_trimmed
df_trimmed = df.drop(index=[0, df.index[-1]])
print(df_trimmed)
# Out:
#   Name  Age
# 1  Bob   30

# %%
import pandas as pd
import numpy as np

data = {
"Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
"Age": [25, np.nan, 35, 40, None],
"City": ["NYC", "LA", None, "Miami", "Boston"],
}

df = pd.DataFrame(data)

# %%
# View the first 5 rows of the DataFrame
print(df.head())
# Out:
#       Name   Age    City
# 0    Alice  25.0     NYC
# 1      Bob   NaN      LA
# 2  Charlie  35.0    None
# 3    David  40.0   Miami
# 4      Eva   NaN  Boston

# %%
# Show where values are missing
print(df.isnull())
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False

# %%
# Count missing values by column
print(df.isnull().sum())
# Out:
# Name    0
# Age     2
# City    1
# dtype: int64

# %%
# Drop rows with missing data
df_cleaned = df.dropna()
print(df_cleaned)
# Out:
#     Name   Age   City
# 0  Alice  25.0    NYC
# 3  David  40.0  Miami

# %%
# Drop columns with missing data
df_cleaned_cols = df.dropna(axis=1)
print(df_cleaned_cols)
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eva

# %%
# Fill missing Age values with the mean
mean_age = df["Age"].mean()
df.fillna({"Age": mean_age}, inplace=True)
print(df)
# Out:
#       Name        Age    City
# 0    Alice  25.000000     NYC
# 1      Bob  33.333333      LA
# 2  Charlie  35.000000    None
# 3    David  40.000000   Miami
# 4      Eva  33.333333  Boston

# %%
# Fill missing City values with "Unknown"
df.fillna({"City": "Unknown"}, inplace=True)
print(df)
# Out:
#       Name        Age     City
# 0    Alice  25.000000      NYC
# 1      Bob  33.333333       LA
# 2  Charlie  35.000000  Unknown
# 3    David  40.000000    Miami
# 4      Eva  33.333333   Boston

# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "Alice", "Bob", "Diana"],
"Age": [25, 30, 35, 25, 30, 40],
"City": ["NYC", "LA", "SF", "NYC", "LA", "NYC"],
}

df = pd.DataFrame(data)

# %%
# Find which rows are duplicates across all columns
duplicates = df.duplicated()
print(duplicates)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
# Drop duplicate rows, keeping the first occurrence
df_no_duplicates = df.drop_duplicates()
print(df_no_duplicates)
# Out:
#       Name  Age City
# 0    Alice   25  NYC
# 1      Bob   30   LA
# 2  Charlie   35   SF
# 5    Diana   40  NYC

# %%
# Drop duplicate rows, keeping only the last occurrence
df_no_duplicates_last = df.drop_duplicates(keep="last")
print(df_no_duplicates_last)
# Out:
#       Name  Age City
# 2  Charlie   35   SF
# 3    Alice   25  NYC
# 4      Bob   30   LA
# 5    Diana   40  NYC

# %%
# Drop all duplicates, removing both the original and duplicate rows
df_no_duplicates_none = df.drop_duplicates(keep=False)
print(df_no_duplicates_none)
# Out:
#       Name  Age City
# 2  Charlie   35   SF
# 5    Diana   40  NYC

# %% [markdown]
# # Section 3: Data Wrangling Essentials

# %%
import pandas as pd

data = {
"fname": ["Alice", "Bob", "Charlie"],
"lname": ["Smith", "Jones", "Brown"],
"ctry": ["USA", "Canada", "UK"],
}

df = pd.DataFrame(data)

# %%
# Change fname to FirstName and lname to LastName
df.rename(columns={"fname": "FirstName", "lname": "LastName"}, inplace=True)
print(df)
# Out:
#   FirstName LastName    ctry
# 0     Alice    Smith     USA
# 1       Bob    Jones  Canada
# 2   Charlie    Brown      UK

# %%
# Change all column names to: ['FirstName', 'LastName', 'Country']
df.columns = ["FirstName", "LastName", "Country"]
print(df)
# Out:
#   FirstName LastName Country
# 0     Alice    Smith     USA
# 1       Bob    Jones  Canada
# 2   Charlie    Brown      UK

# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie"],
"Dept": ["HR", "Finance", "IT"],
"Sal": [60000, 70000, 80000],
}

df = pd.DataFrame(data)

# %%
# Rename Dept to Department and Sal to Salary
df.rename(columns={"Dept": "Department", "Sal": "Salary"}, inplace=True)
print(df)
# Out:
#       Name Department  Salary
# 0    Alice         HR   60000
# 1      Bob    Finance   70000
# 2  Charlie         IT   80000

# %%
# Reorder columns so Salary appears first, followed by Name and Department
df = df[["Salary", "Name", "Department"]]
print(df)
# Out:
#    Salary     Name Department
# 0   60000    Alice         HR
# 1   70000      Bob    Finance
# 2   80000  Charlie         IT

# %%
# Print the updated DataFrame
print(df)
# Out:
#    Salary     Name Department
# 0   60000    Alice         HR
# 1   70000      Bob    Finance
# 2   80000  Charlie         IT

# %%
import pandas as pd

data = {
"Store": ["A", "A", "A", "B", "B", "C", "C", "C", "C"],
"Product": ["Apples", "Oranges", "Bananas", "Apples", "Bananas", "Oranges", "Apples", "Bananas", "Bananas"],
"Sales": [100, 80, 90, 120, 110, 60, 95, 85, 75],
"Profit": [30, 25, 20, 40, 35, 15, 32, 22, 18],
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#   Store  Product  Sales  Profit
# 0     A   Apples    100      30
# 1     A  Oranges     80      25
# 2     A  Bananas     90      20
# 3     B   Apples    120      40
# 4     B  Bananas    110      35

# %%
# Group the data by Store and use .agg() to find the average Sales and average Profit for each store
df_grouped = df.groupby("Store").agg({"Sales": "mean", "Profit": "mean"})
print(df_grouped)
# Out:
#         Sales  Profit
# Store
# A       90.00   25.00
# B      115.00   37.50
# C       78.75   21.75

# %%
# Group by Product and get the maximum Sales and minimum Profit
df_product_grouped = df.groupby("Product").agg({"Sales": "max", "Profit": "min"})
print(df_product_grouped)
# Out:
#          Sales  Profit
# Product
# Apples     120      30
# Bananas    110      18
# Oranges     80      15

# %%
# Group by Store and return the average Sales and maximum Profit, but name the columns Avg_Sales and Max_Profit
df_store_grouped = df.groupby("Store").agg(Avg_Sales=("Sales", "mean"), Max_Profit=("Profit", "max"))
print(df_store_grouped)
# Out:
#        Avg_Sales  Max_Profit
# Store
# A          90.00          30
# B         115.00          40
# C          78.75          32

# %%
# Group by both Store and Product, and find the total Sales using .agg()
df_store_product_grouped = df.groupby(["Store", "Product"]).agg(Total_Sales=("Sales", "sum"))
print(df_store_product_grouped)
# Out:
#                Total_Sales
# Store Product
# A     Apples           100
#       Bananas           90
#       Oranges           80
# B     Apples           120
#       Bananas          110
# C     Apples            95
#       Bananas          160
#       Oranges           60

# %%
import pandas as pd

df_customers = pd.DataFrame({
"CustomerName": ["Alice", "Bob", "Charlie"]
}, index=[101, 102, 103])

df_orders = pd.DataFrame({
"OrderTotal": [250, 300, 400]
}, index=[101, 102, 103])

# %%
# Join df_orders to df_customers on the index
df_joined = df_customers.join(df_orders)
print(df_joined)
# Out:
#     CustomerName  OrderTotal
# 101        Alice         250
# 102          Bob         300
# 103      Charlie         400

# %%
# Add a new column to df_customers with city data from df_cities
df_cities = pd.DataFrame({
"City": ["NYC", "LA", "Chicago"]    
}, index=[101, 102, 103])
df_customers["City"] = df_cities["City"]
print(df_customers)
# Out:
#     CustomerName     City
# 101        Alice      NYC
# 102          Bob       LA
# 103      Charlie  Chicago

# %% [markdown]
# # Week 2 Quiz: Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = {
"genre": [
    "Pop","Rock","Hip-Hop","Electronic","Pop","Rock","Hip-Hop","Electronic",
    "Pop","Rock","Hip-Hop","Electronic","Pop","Rock","Hip-Hop","Electronic",
    "Pop","Rock","Hip-Hop","Electronic"
],
"streams": [
    120,90,150,70,130,95,140,80,
    110,85,155,75,125,100,145,78,
    118,92,160,82
],
"likes": [
    30,20,50,15,35,22,48,18,
    28,19,55,16,32,25,47,17,
    29,21,60,19
],
"shares": [
    10,8,20,5,12,9,18,6,
    9,7,22,5,11,10,19,6,
    10,8,25,7
],
"year": [
    2020,2020,2020,2020,2021,2021,2021,2021,
    2022,2022,2022,2022,2023,2023,2023,2023,
    2024,2024,2024,2024
]
}

df = pd.DataFrame(data)

# %% [markdown]
# ## Bar Plot

# %%
# Create a bar plot in which the x-axis represents genre and the y-axis represents streams. Title it "Streams by Genre"
genre_streams = df.groupby("genre")["streams"].sum()

plt.bar(genre.index, genre_streams.values)

plt.xlabel("Genre")
plt.ylabel("Streams")
plt.title("Streams by Genre")
plt.xticks(rotation=90, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# Create a scatter plot in which the x-axis represents likes and the y-axis represents streams. Title it "Streams vs Likes"
plt.scatter(df["likes"], df["streams"])

plt.xlabel("Likes")
plt.ylabel("Streams")
plt.title("Streams vs Likes")

plt.show()

# %% [markdown]
# ## Histogram

# %%
# Create a histogram that utilizes the streams column to measure stream distribution and is titled "Streams Distribution"
plt.hist(df["streams"])

plt.xlabel("Streams")
plt.ylabel("Frequency")
plt.title("Streams Distribution")

plt.show()
